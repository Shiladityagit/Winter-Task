# %% [markdown]
# # Book Recommendation System

# %% [markdown]
# ## Importing libraries and dataset

# %%
import pandas as pd
import numpy as np

# %%
Books=pd.read_csv('Books.csv')
Books
# Out:
# C:\Users\manda\AppData\Local\Temp\ipykernel_10564\3104042840.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   Books=pd.read_csv('Books.csv')
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# ...

# %%
Users=pd.read_csv('Users.csv')
Users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
Ratings=pd.read_csv('Ratings.csv')
Ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %% [markdown]
# ## Analysing the data

# %%
Books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
Books.duplicated().sum()
# Out:
# 0

# %%
Users.isnull().sum() # We will not use age,so null in age will not matter.
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
Users.duplicated().sum()
# Out:
# 0

# %%
Ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
Ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Popularity based recommendation system

# %% [markdown]
# ### (Top books of the platform)

# %%
books_with_ratings=Ratings.merge(Books,on='ISBN')

# %%
num_rating = books_with_ratings.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
books_with_ratings['Book-Rating'] = pd.to_numeric(books_with_ratings['Book-Rating'], errors='coerce')

# %%
# Check data type
print(books_with_ratings['Book-Rating'].dtype)

# Convert data type to numeric
books_with_ratings['Book-Rating'] = pd.to_numeric(books_with_ratings['Book-Rating'], errors='coerce')

# Check for missing values
print(books_with_ratings['Book-Rating'].isnull().sum())

# Check for non-numeric values
print(books_with_ratings['Book-Rating'].unique())

# Group by 'Book-Title' and compute mean
avg_rating_df = books_with_ratings.groupby('Book-Title')['Book-Rating'].mean().reset_index()

# Rename the column
avg_rating_df.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)
# Out:
# int64
# 0
# [ 0  5  9  8  6  7  4 10  3  2  1]

# %%
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popular_books_df = num_rating.merge(avg_rating_df,on='Book-Title')
popular_books_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
popular_books_df = popular_books_df[popular_books_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_books_df = popular_books_df.merge(Books,on='Book-Title').drop_duplicates('Book-Title')

# %%
popular_books_df.head(50)
# Out:
#                                             Book-Title  num_ratings  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 3         Harry Potter and the Goblet of Fire (Book 4)          387
# 5       Harry Potter and the Sorcerer's Stone (Book 1)          278
# 9    Harry Potter and the Order of the Phoenix (Boo...          347
# 13    Harry Potter and the Chamber of Secrets (Book 2)          556
# 16   The Hobbit : The Enchanting Prelude to The Lor...          281
# 17   The Fellowship of the Ring (The Lord of the Ri...          368
# 26   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 28      The Two Towers (The Lord of the Rings, Part 2)          260
# 39                               To Kill a Mockingbird          510
# 47                                   The Da Vinci Code          898
# 53                  The Five People You Meet in Heaven          430
# 55                              The Catcher in the Rye          449
# ...

# %%
popular_books_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg'

# %% [markdown]
# ## Collaborative filtering based system

# %%
books_with_ratings.groupby('User-ID').count()['Book-Rating']
# Out:
# User-ID
# 2          1
# 8         17
# 9          3
# 10         1
# 12         1
#           ..
# 278846     1
# 278849     4
# 278851    23
# 278852     1
# 278854     8
# Name: Book-Rating, Length: 92106, dtype: int64

# %%
x=books_with_ratings.groupby('User-ID').count()['Book-Rating']>150

# %%
good_users=x[x].index

# %%
good_users
# Out:
# Index([   254,   1733,   1903,   2033,   2110,   2276,   2766,   2891,   2977,
#          3363,
#        ...
#        274301, 274308, 274808, 275970, 276680, 277427, 277478, 277639, 278188,
#        278418],
#       dtype='int64', name='User-ID', length=1115)

# %%
filtered_rating = books_with_ratings[books_with_ratings['User-ID'].isin(good_users)]

# %%
y=filtered_rating.groupby('Book-Title').count()['Book-Rating']>50
famous_books=y[y].index

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 67          8253  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# ...          ...         ...          ...                     ...
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030363   274808  0449701913            0              Homecoming
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#              Book-Author Year-Of-Publication                Publisher  \
# 63       Nicholas Sparks                1996             Warner Books
# ...

# %%
 pt=final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             254     1733    1903    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (844, 844)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:6]
    
    data = []
    for i in similar_items:
        print(pt.index[i[0]])
    
    return data

# %% [markdown]
# ## Working of the model

# %%
recommend('The Da Vinci Code')
# Out:
# Angels &amp; Demons
# Middlesex: A Novel
# The Blue Nowhere : A Novel
# Touching Evil
# TickTock
# []

# %%
recommend('The Notebook')
# Out:
# Nights in Rodanthe
# A Walk to Remember
# The Rescue
# Toxin
# Suzanne's Diary for Nicholas
# []

# %%
recommend('1984')
# Out:
# Animal Farm
# Lord of the Flies
# Slaughterhouse Five or the Children's Crusade: A Duty Dance With Death
# The Handmaid's Tale
# The Catcher in the Rye
# []

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# Harry Potter and the Order of the Phoenix (Book 5)
# []
